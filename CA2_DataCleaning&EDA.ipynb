# %% [markdown]
# Dataset LINK = https://www.kaggle.com/datasets/obeykhadija/drug-consumptions-uci

# %% [markdown]
# ## Content before Data Cleaning and EDA
#
# __Feature Attributes for Quantified Data:__
#
# * ID: is a number of records in an original database. Cannot be related to the participant. It can be used for reference only.
# * Age (Real) is the age of participant
# * Gender: Male or Female
# * Education: level of education of participant
# * Country: country of origin of the participant
# * Ethnicity: ethnicity of participant
# * Nscore (Real) is NEO-FFI-R Neuroticism
# * Escore (Real) is NEO-FFI-R Extraversion
# * Oscore (Real) is NEO-FFI-R Openness to experience.
# * Ascore (Real) is NEO-FFI-R Agreeableness.
# * Cscore (Real) is NEO-FFI-R Conscientiousness.
# * Impulsive (Real) is impulsiveness measured by BIS-11
# * SS (Real) is sensation seeing measured by ImpSS
# * Alcohol: alcohol consumption
# * Amphet: amphetamines consumption
# * Amyl: nitrite consumption
# * Benzos: benzodiazepine consumption
# * Caff: caffeine consumption
# * Cannabis: marijuana consumption
# * Choc: chocolate consumption
# * Coke: cocaine consumption
# * Crack: crack cocaine consumption
# * Ecstasy: ecstasy consumption
# * Heroin: heroin consumption
# * Ketamine: ketamine consumption
# * Legalh: legal highs consumption
# * LSD: LSD consumption
# * Meth: methadone consumption
# * Mushroom: magic mushroom consumption
# * Nicotine: nicotine consumption
# * Semer: class of fictitious drug Semeron consumption (i.e. control)
# * VSA: class of volatile substance abuse consumption
#
# __Rating's for Drug Use:__
#
# * CL0 Never Used
# * CL1 Used over a Decade Ago
# * CL2 Used in Last Decade
# * CL3 Used in Last Year 59
# * CL4 Used in Last Month
# * CL5 Used in Last Week
# * CL6 Used in Last Day

# %% [markdown]
# # Data Cleaning

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Drug_Consumption.csv")

# %%
pd.set_option('display.max_columns', None)

# %%
display(df.head())
# Out:
#    ID    Age Gender                          Education Country Ethnicity  \
# 0   2  25-34      M                   Doctorate degree      UK     White
# 1   3  35-44      M  Professional certificate/ diploma      UK     White
# 2   4  18-24      F                     Masters degree      UK     White
# 3   5  35-44      F                   Doctorate degree      UK     White
# 4   6    65+      F            Left school at 18 years  Canada     White
#
#     Nscore   Escore   Oscore   AScore   Cscore  Impulsive       SS Alcohol  \
# 0 -0.67825  1.93886  1.43533  0.76096 -0.14277   -0.71126 -0.21575     CL5
# 1 -0.46725  0.80523 -0.84732 -1.62090 -1.01450   -1.37983  0.40148     CL6
# 2 -0.14882 -0.80615 -0.01928  0.59042  0.58489   -1.37983 -1.18084     CL4
# 3  0.73545 -1.63340 -0.45174 -0.30172  1.30612   -0.21712 -0.21575     CL4
# 4 -0.67825 -0.30033 -1.55521  2.03972  1.63088   -1.37983 -1.54858     CL2
#
#   Amphet Amyl Benzos Caff Cannabis Choc Coke Crack Ecstasy Heroin Ketamine  \
# 0    CL2  CL2    CL0  CL6      CL4  CL6  CL3   CL0     CL4    CL0      CL2
# 1    CL0  CL0    CL0  CL6      CL3  CL4  CL0   CL0     CL0    CL0      CL0
# 2    CL0  CL0    CL3  CL5      CL2  CL4  CL2   CL0     CL0    CL0      CL2
# 3    CL1  CL1    CL0  CL6      CL3  CL6  CL0   CL0     CL1    CL0      CL0
# 4    CL0  CL0    CL0  CL6      CL0  CL4  CL0   CL0     CL0    CL0      CL0
#
#   Legalh  LSD Meth Mushrooms Nicotine Semer  VSA
# 0    CL0  CL2  CL3       CL0      CL4   CL0  CL0
# 1    CL0  CL0  CL0       CL1      CL0   CL0  CL0
# 2    CL0  CL0  CL0       CL0      CL2   CL0  CL0
# 3    CL1  CL0  CL0       CL2      CL2   CL0  CL0
# 4    CL0  CL0  CL0       CL0      CL6   CL0  CL0

# %%
df = df.drop(columns=["ID"])

# %%
display(df[df["Semer"] != "CL0"])
# Out:
#         Age Gender                                          Education  \
# 726   25-34      F                            Left school at 16 years
# 816   18-24      M  Some college or university, no certificate or ...
# 1515  18-24      M  Some college or university, no certificate or ...
# 1532  18-24      F  Some college or university, no certificate or ...
# 1697  35-44      F                                  University degree
# 1768  18-24      M                            Left school at 18 years
# 1805  18-24      F                            Left school at 17 years
# 1822  18-24      F                                  University degree
#
#         Country          Ethnicity   Nscore   Escore   Oscore   AScore  \
# 726   Australia              White -0.58016  0.32197  0.14143 -0.60633
# 816   Australia              Asian -0.67825  1.74091  0.72330  0.13136
# 1515        USA              White -0.24649 -0.80615 -1.27553 -1.34289
# 1532        USA              Other -0.46725  0.80523  0.29338  2.03972
# 1697        USA              White  1.98437 -0.80615  2.15324  0.76096
# 1768        USA  Mixed-White/Black -0.34799  1.28610  1.06238 -0.01729
# 1805        USA              White  1.23461  1.11406  1.06238 -1.47955
# 1822        USA              White  0.22393 -0.30033  0.88309  1.28610
#
#        Cscore  Impulsive       SS Alcohol Amphet Amyl Benzos Caff Cannabis  \
# 726   0.12331    1.29221  0.76540     CL6    CL2  CL2    CL2  CL6      CL6
# 816   0.41594    0.88113  1.92173     CL3    CL0  CL0    CL0  CL6      CL4
# 1515 -1.92173   -0.71126  0.07987     CL0    CL2  CL3    CL2  CL3      CL4
# 1532  1.81175   -1.37983 -0.21575     CL5    CL6  CL0    CL4  CL6      CL3
# 1697 -0.00665    1.29221  1.92173     CL6    CL0  CL0    CL3  CL5      CL6
# 1768 -0.52745    0.52975  1.22470     CL4    CL3  CL0    CL3  CL6      CL6
# 1805  0.12331    0.88113  1.92173     CL4    CL3  CL0    CL2  CL6      CL6
# 1822 -0.00665    0.88113  0.07987     CL4    CL0  CL0    CL2  CL5      CL6
#
#      Choc Coke Crack Ecstasy Heroin Ketamine Legalh  LSD Meth Mushrooms  \
# 726   CL5  CL2   CL2     CL2    CL2      CL2    CL0  CL4  CL2       CL6
# 816   CL5  CL0   CL0     CL3    CL0      CL0    CL0  CL5  CL0       CL5
# 1515  CL1  CL3   CL2     CL1    CL2      CL1    CL2  CL1  CL2       CL4
# 1532  CL6  CL4   CL0     CL4    CL0      CL4    CL3  CL2  CL0       CL3
# 1697  CL4  CL2   CL0     CL2    CL0      CL2    CL2  CL2  CL0       CL2
# 1768  CL6  CL0   CL0     CL3    CL0      CL4    CL3  CL6  CL3       CL3
# 1805  CL3  CL5   CL2     CL4    CL2      CL1    CL4  CL1  CL0       CL1
# 1822  CL5  CL2   CL0     CL0    CL0      CL0    CL2  CL3  CL0       CL3
#
#      Nicotine Semer  VSA
# 726       CL6   CL2  CL2
# 816       CL4   CL3  CL0
# 1515      CL2   CL3  CL1
# 1532      CL4   CL4  CL3
# 1697      CL6   CL2  CL0
# 1768      CL3   CL1  CL3
# 1805      CL6   CL1  CL2
# 1822      CL5   CL2  CL0

# %% [markdown]
# Potentional Liars => Next step is to delete them

# %%
df = df[df["Semer"] == "CL0"]

# %%
#Check
display(df[df["Semer"] != "CL0"])
# Out:
# Empty DataFrame
# Columns: [Age, Gender, Education, Country, Ethnicity, Nscore, Escore, Oscore, AScore, Cscore, Impulsive, SS, Alcohol, Amphet, Amyl, Benzos, Caff, Cannabis, Choc, Coke, Crack, Ecstasy, Heroin, Ketamine, Legalh, LSD, Meth, Mushrooms, Nicotine, Semer, VSA]
# Index: []

# %% [markdown]
# Drop the "Liar Check" (Semer) column, as it is no longer necessary.

# %%
df = df.drop(columns=["Semer"])

# %% [markdown]
# Check for duplicates

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Check for missing values

# %%
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Rename columns

# %%
df = df.rename(columns={
    "Nscore"    : "Neuroticism",
    "Escore"    : "Extraversion",
    "Oscore"    : "Openness",
    "AScore"    : "Agreeableness",
    "Cscore"    : "Conscientiousness",
    "Impulsive" : "Impulsivity",
    "SS"        : "Sensation Seeking",
    "Amphet"    : "Amphetamines",
    "Amyl"      : "Amyl Nitrite",
    "Benzos"    : "Benzodiazepines",
    "Caff"      : "Caffeine",
    "Choc"      : "Chocolate",
    "Coke"      : "Cocaine",
    "Crack"     : "Crack Cocaine",
    "Legalh"    : "Legal Highs",
    "Meth"      : "Methamphetamine",
    "Mushrooms" : "Magic Mushrooms",
    "VSA"       : "Volatile Substance Abuse",
})

# %% [markdown]
# Rename rating

# %%
frequency_map = {
    "CL0": "Never Used",
    "CL1": "Over a Decade Ago",
    "CL2": "Last Decade",
    "CL3": "Last Year",
    "CL4": "Last Month",
    "CL5": "Last Week",
    "CL6": "Last Day",
}

# %%
drug_cols = [
    "Alcohol", "Amphetamines", "Amyl Nitrite", "Benzodiazepines",
    "Caffeine", "Cannabis", "Chocolate", "Cocaine", "Crack Cocaine",
    "Ecstasy", "Heroin", "Ketamine", "Legal Highs", "LSD",
    "Methamphetamine", "Magic Mushrooms", "Nicotine",
    "Volatile Substance Abuse"
]
 
for col in drug_cols:
    df[col] = df[col].map(frequency_map)

# %% [markdown]
# Rename Gender values

# %%
df["Gender"] = df["Gender"].map({"M": "Male", "F": "Female"})

# %%
display(df.head())
# Out:
#      Age  Gender                          Education Country Ethnicity  \
# 0  25-34    Male                   Doctorate degree      UK     White
# 1  35-44    Male  Professional certificate/ diploma      UK     White
# 2  18-24  Female                     Masters degree      UK     White
# 3  35-44  Female                   Doctorate degree      UK     White
# 4    65+  Female            Left school at 18 years  Canada     White
#
#    Neuroticism  Extraversion  Openness  Agreeableness  Conscientiousness  \
# 0     -0.67825       1.93886   1.43533        0.76096           -0.14277
# 1     -0.46725       0.80523  -0.84732       -1.62090           -1.01450
# 2     -0.14882      -0.80615  -0.01928        0.59042            0.58489
# 3      0.73545      -1.63340  -0.45174       -0.30172            1.30612
# 4     -0.67825      -0.30033  -1.55521        2.03972            1.63088
#
#    Impulsivity  Sensation Seeking      Alcohol       Amphetamines  \
# 0     -0.71126           -0.21575    Last Week        Last Decade
# 1     -1.37983            0.40148     Last Day         Never Used
# 2     -1.37983           -1.18084   Last Month         Never Used
# 3     -0.21712           -0.21575   Last Month  Over a Decade Ago
# 4     -1.37983           -1.54858  Last Decade         Never Used
#
#         Amyl Nitrite Benzodiazepines   Caffeine     Cannabis   Chocolate  \
# 0        Last Decade      Never Used   Last Day   Last Month    Last Day
# 1         Never Used      Never Used   Last Day    Last Year  Last Month
# 2         Never Used       Last Year  Last Week  Last Decade  Last Month
# 3  Over a Decade Ago      Never Used   Last Day    Last Year    Last Day
# 4         Never Used      Never Used   Last Day   Never Used  Last Month
#
#        Cocaine Crack Cocaine            Ecstasy      Heroin     Ketamine  \
# 0    Last Year    Never Used         Last Month  Never Used  Last Decade
# 1   Never Used    Never Used         Never Used  Never Used   Never Used
# 2  Last Decade    Never Used         Never Used  Never Used  Last Decade
# 3   Never Used    Never Used  Over a Decade Ago  Never Used   Never Used
# 4   Never Used    Never Used         Never Used  Never Used   Never Used
#
#          Legal Highs          LSD Methamphetamine    Magic Mushrooms  \
# 0         Never Used  Last Decade       Last Year         Never Used
# 1         Never Used   Never Used      Never Used  Over a Decade Ago
# 2         Never Used   Never Used      Never Used         Never Used
# 3  Over a Decade Ago   Never Used      Never Used        Last Decade
# 4         Never Used   Never Used      Never Used         Never Used
#
#       Nicotine Volatile Substance Abuse
# 0   Last Month               Never Used
# 1   Never Used               Never Used
# 2  Last Decade               Never Used
# 3  Last Decade               Never Used
# 4     Last Day               Never Used

# %%
display(df.describe())
# Out:
#        Neuroticism  Extraversion     Openness  Agreeableness  \
# count  1876.000000   1876.000000  1876.000000    1876.000000
# mean     -0.000718     -0.001646    -0.002915      -0.000169
# std       0.998682      0.997596     0.995866       0.996730
# min      -3.464360     -3.273930    -3.273930      -3.464360
# 25%      -0.678250     -0.695090    -0.717270      -0.606330
# 50%       0.042570      0.003320    -0.019280      -0.017290
# 75%       0.629670      0.637790     0.723300       0.760960
# max       3.273930      3.273930     2.901610       3.464360
#
#        Conscientiousness  Impulsivity  Sensation Seeking
# count        1876.000000  1876.000000        1876.000000
# mean           -0.000391     0.005412          -0.006782
# std             0.997923     0.954389           0.961949
# min            -3.464360    -2.555240          -2.078480
# 25%            -0.652530    -0.711260          -0.525930
# 50%            -0.006650    -0.217120           0.079870
# 75%             0.628243     0.529750           0.765400
# max             3.464360     2.901610           1.921730

# %%
num_cols = [
    "Neuroticism", "Extraversion", "Openness",
    "Agreeableness", "Conscientiousness", "Impulsivity", "Sensation Seeking"
]

# %%
for col in num_cols:
    extreme = df[(df[col] > 3.5) | (df[col] < -3.5)].shape[0]
    print(f"  {col}: {extreme} extreme values")
# Out:
#   Neuroticism: 0 extreme values
#   Extraversion: 0 extreme values
#   Openness: 0 extreme values
#   Agreeableness: 0 extreme values
#   Conscientiousness: 0 extreme values
#   Impulsivity: 0 extreme values
#   Sensation Seeking: 0 extreme values

# %% [markdown]
# Just checking, even if there are outliers. I would not probably delete them.

# %% [markdown]
# ## Final check for Data Cleaning

# %%
print(df.shape)
# Out:
# (1876, 30)

# %%
display(df.head())
# Out:
#      Age  Gender                          Education Country Ethnicity  \
# 0  25-34    Male                   Doctorate degree      UK     White
# 1  35-44    Male  Professional certificate/ diploma      UK     White
# 2  18-24  Female                     Masters degree      UK     White
# 3  35-44  Female                   Doctorate degree      UK     White
# 4    65+  Female            Left school at 18 years  Canada     White
#
#    Neuroticism  Extraversion  Openness  Agreeableness  Conscientiousness  \
# 0     -0.67825       1.93886   1.43533        0.76096           -0.14277
# 1     -0.46725       0.80523  -0.84732       -1.62090           -1.01450
# 2     -0.14882      -0.80615  -0.01928        0.59042            0.58489
# 3      0.73545      -1.63340  -0.45174       -0.30172            1.30612
# 4     -0.67825      -0.30033  -1.55521        2.03972            1.63088
#
#    Impulsivity  Sensation Seeking      Alcohol       Amphetamines  \
# 0     -0.71126           -0.21575    Last Week        Last Decade
# 1     -1.37983            0.40148     Last Day         Never Used
# 2     -1.37983           -1.18084   Last Month         Never Used
# 3     -0.21712           -0.21575   Last Month  Over a Decade Ago
# 4     -1.37983           -1.54858  Last Decade         Never Used
#
#         Amyl Nitrite Benzodiazepines   Caffeine     Cannabis   Chocolate  \
# 0        Last Decade      Never Used   Last Day   Last Month    Last Day
# 1         Never Used      Never Used   Last Day    Last Year  Last Month
# 2         Never Used       Last Year  Last Week  Last Decade  Last Month
# 3  Over a Decade Ago      Never Used   Last Day    Last Year    Last Day
# 4         Never Used      Never Used   Last Day   Never Used  Last Month
#
#        Cocaine Crack Cocaine            Ecstasy      Heroin     Ketamine  \
# 0    Last Year    Never Used         Last Month  Never Used  Last Decade
# 1   Never Used    Never Used         Never Used  Never Used   Never Used
# 2  Last Decade    Never Used         Never Used  Never Used  Last Decade
# 3   Never Used    Never Used  Over a Decade Ago  Never Used   Never Used
# 4   Never Used    Never Used         Never Used  Never Used   Never Used
#
#          Legal Highs          LSD Methamphetamine    Magic Mushrooms  \
# 0         Never Used  Last Decade       Last Year         Never Used
# 1         Never Used   Never Used      Never Used  Over a Decade Ago
# 2         Never Used   Never Used      Never Used         Never Used
# 3  Over a Decade Ago   Never Used      Never Used        Last Decade
# 4         Never Used   Never Used      Never Used         Never Used
#
#       Nicotine Volatile Substance Abuse
# 0   Last Month               Never Used
# 1   Never Used               Never Used
# 2  Last Decade               Never Used
# 3  Last Decade               Never Used
# 4     Last Day               Never Used

# %% [markdown]
# Save

# %%
df.to_csv("drug_consumption_clean.csv", index=False)

# %% [markdown]
# # EDA

# %%
display(df.head())
# Out:
#      Age  Gender                          Education Country Ethnicity  \
# 0  25-34    Male                   Doctorate degree      UK     White
# 1  35-44    Male  Professional certificate/ diploma      UK     White
# 2  18-24  Female                     Masters degree      UK     White
# 3  35-44  Female                   Doctorate degree      UK     White
# 4    65+  Female            Left school at 18 years  Canada     White
#
#    Neuroticism  Extraversion  Openness  Agreeableness  Conscientiousness  \
# 0     -0.67825       1.93886   1.43533        0.76096           -0.14277
# 1     -0.46725       0.80523  -0.84732       -1.62090           -1.01450
# 2     -0.14882      -0.80615  -0.01928        0.59042            0.58489
# 3      0.73545      -1.63340  -0.45174       -0.30172            1.30612
# 4     -0.67825      -0.30033  -1.55521        2.03972            1.63088
#
#    Impulsivity  Sensation Seeking      Alcohol       Amphetamines  \
# 0     -0.71126           -0.21575    Last Week        Last Decade
# 1     -1.37983            0.40148     Last Day         Never Used
# 2     -1.37983           -1.18084   Last Month         Never Used
# 3     -0.21712           -0.21575   Last Month  Over a Decade Ago
# 4     -1.37983           -1.54858  Last Decade         Never Used
#
#         Amyl Nitrite Benzodiazepines   Caffeine     Cannabis   Chocolate  \
# 0        Last Decade      Never Used   Last Day   Last Month    Last Day
# 1         Never Used      Never Used   Last Day    Last Year  Last Month
# 2         Never Used       Last Year  Last Week  Last Decade  Last Month
# 3  Over a Decade Ago      Never Used   Last Day    Last Year    Last Day
# 4         Never Used      Never Used   Last Day   Never Used  Last Month
#
#        Cocaine Crack Cocaine            Ecstasy      Heroin     Ketamine  \
# 0    Last Year    Never Used         Last Month  Never Used  Last Decade
# 1   Never Used    Never Used         Never Used  Never Used   Never Used
# 2  Last Decade    Never Used         Never Used  Never Used  Last Decade
# 3   Never Used    Never Used  Over a Decade Ago  Never Used   Never Used
# 4   Never Used    Never Used         Never Used  Never Used   Never Used
#
#          Legal Highs          LSD Methamphetamine    Magic Mushrooms  \
# 0         Never Used  Last Decade       Last Year         Never Used
# 1         Never Used   Never Used      Never Used  Over a Decade Ago
# 2         Never Used   Never Used      Never Used         Never Used
# 3  Over a Decade Ago   Never Used      Never Used        Last Decade
# 4         Never Used   Never Used      Never Used         Never Used
#
#       Nicotine Volatile Substance Abuse
# 0   Last Month               Never Used
# 1   Never Used               Never Used
# 2  Last Decade               Never Used
# 3  Last Decade               Never Used
# 4     Last Day               Never Used

# %% [markdown]
# Discovering unique Education values

# %%
display(df["Education"].value_counts())
# Out:
# Education
# Some college or university, no certificate or degree    503
# University degree                                       478
# Masters degree                                          283
# Professional certificate/ diploma                       269
# Left school at 18 years                                  99
# Left school at 16 years                                  98
# Doctorate degree                                         89
# Left school at 17 years                                  29
# Left school before 16 years                              28
# Name: count, dtype: int64

# %% [markdown]
# Discovering unique Age values

# %%
display(df["Age"].value_counts())
# Out:
# Age
# 18-24    637
# 25-34    480
# 35-44    354
# 45-54    294
# 55-64     93
# 65+       18
# Name: count, dtype: int64
